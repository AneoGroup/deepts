# %% [markdown]
# # Sampling DeepAR
# Model: DeepAR
#
# Dataset: Exchange rate
#
# This notebooks looks at the potential for specific random seeds to produce bad results when sampling from different models. The differences, in terms of evaluation metrics, between samples from the same architecture trained from different random seeds are calculated. Then we look for specific random seeds that produce bad model performance across the architecture.
#
# The seeds we have sampled from: 7, 84, 63, 26

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from src.metrics import *

# %%
# id used to differentiate between plots from different models/datasets
id = "deepar_exchange"
root_path = "/datadrive/experiments/deep_ar/exchange_rate/1B"
num_timeseries = 8
seeds = [7, 84, 63, 26]

# %% [markdown]
# ### Differences in terms of error metrics

# %%
def load_samples(path):
    samples = []
    for f in os.listdir(path):
        if f.endswith("metrics.csv"):
            samples.append(pd.read_csv(f"{path}/{f}", index_col=0).rename_axis("index"))
    return samples

# %%
path0 = f"{root_path}/repetition07/samples"

# %%
samples0 = load_samples(path0)

# %%
report_experiment_results(samples0)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 0.00023211172961005555
# 		Std: 7.3480202830899005e-06
# 		Variance: 0.00271072320296446
#
# 	Worst seeds:
# 		Mean: 0.0002441465330775827
# 		Std: 3.4493905332055874e-06
# 		Variance: 0.0018572534900158644
#
# 	Best seeds:
# 		Mean: 0.00021865805319976062
# 		Std: 2.298238314324408e-06
# 		Variance: 0.0015159941976889968
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 1.7614128004018048
# 		Std: 0.04091967685475993
# 		Variance: 0.20228612620434436
#
# 	Worst seeds:
# 		Mean: 1.8278768062591553
# 		Std: 0.017191840335726738
# 		Variance: 0.13111765682697296
#
# 	Best seeds:
# 		Mean: 1.692102074623108
# 		Std: 0.020406784489750862
# 		Variance: 0.142852321267128
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 0.011071396900593675
# 		Std: 0.00013905592355176758
# 		Variance: 0.011792197570926616
#
# 	Worst seeds:
# 		Mean: 0.011309457011520863
# 		Std: 6.405643944162875e-05
# 		Variance: 0.008003526367247105
#
# 	Best seeds:
# 		Mean: 0.01082012802362442
# 		Std: 5.622562821372412e-05
# 		Variance: 0.00749837514013052

# %%
path1 = f"{root_path}/repetition{seeds[1]}/samples"

# %%
samples1 = load_samples(path1)

# %%
report_experiment_results(samples1)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 0.00019647966949819115
# 		Std: 9.004177772543934e-06
# 		Variance: 0.0030006962146381854
#
# 	Worst seeds:
# 		Mean: 0.00021266280964482576
# 		Std: 5.078434242022922e-06
# 		Variance: 0.00225353823043406
#
# 	Best seeds:
# 		Mean: 0.00018171043484471738
# 		Std: 3.91269395549898e-06
# 		Variance: 0.0019780530128628016
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 4.075303362071127
# 		Std: 0.0758593374557062
# 		Variance: 0.2754257385498062
#
# 	Worst seeds:
# 		Mean: 4.220197677612305
# 		Std: 0.03958249092102051
# 		Variance: 0.19895349442958832
#
# 	Best seeds:
# 		Mean: 3.9626998901367188
# 		Std: 0.037962932139635086
# 		Variance: 0.19484078884124756
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 0.014730819149594333
# 		Std: 0.00022341372155585982
# 		Variance: 0.014947030526357395
#
# 	Worst seeds:
# 		Mean: 0.0151591245085001
# 		Std: 0.0001081024092854932
# 		Variance: 0.010397231206297874
#
# 	Best seeds:
# 		Mean: 0.01436786912381649
# 		Std: 8.625874761492014e-05
# 		Variance: 0.009287558495998383

# %%
path2 = f"{root_path}/repetition{seeds[2]}/samples"

# %%
samples2 = load_samples(path2)

# %%
report_experiment_results(samples2)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 0.027658840081574213
# 		Std: 9.429825106928126e-05
# 		Variance: 0.009710728657998907
#
# 	Worst seeds:
# 		Mean: 0.027827227488160133
# 		Std: 4.5307446271181107e-05
# 		Variance: 0.006731080822646618
#
# 	Best seeds:
# 		Mean: 0.02749466896057129
# 		Std: 2.3775735826347955e-05
# 		Variance: 0.004876037128269672
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 48.429297303216615
# 		Std: 0.06135026088928218
# 		Variance: 0.24768984817566136
#
# 	Worst seeds:
# 		Mean: 48.53850555419922
# 		Std: 0.02842753753066063
# 		Variance: 0.16860467195510864
#
# 	Best seeds:
# 		Mean: 48.329750061035156
# 		Std: 0.023352671414613724
# 		Variance: 0.1528158038854599
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 0.19844081233423247
# 		Std: 0.00019631661316682215
# 		Variance: 0.014011303050281303
#
# 	Worst seeds:
# 		Mean: 0.19881363213062286
# 		Std: 0.0001420972403138876
# 		Variance: 0.011920454911887646
#
# 	Best seeds:
# 		Mean: 0.19813592731952667
# 		Std: 4.369396629044786e-05
# 		Variance: 0.006610141135752201

# %%
path3 = f"{root_path}/repetition{seeds[3]}/samples"

# %%
samples3 = load_samples(path3)

# %%
report_experiment_results(samples3)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 0.07998988582793584
# 		Std: 0.00019448456768923135
# 		Variance: 0.013945772394859718
#
# 	Worst seeds:
# 		Mean: 0.08033721148967743
# 		Std: 0.00010389587259851396
# 		Variance: 0.010192932561039925
#
# 	Best seeds:
# 		Mean: 0.07966909557580948
# 		Std: 4.7423411160707474e-05
# 		Variance: 0.0068864659406244755
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 47.38877056998718
# 		Std: 0.06046713156106109
# 		Variance: 0.2459006538443139
#
# 	Worst seeds:
# 		Mean: 47.505123138427734
# 		Std: 0.025803206488490105
# 		Variance: 0.16063375771045685
#
# 	Best seeds:
# 		Mean: 47.29784393310547
# 		Std: 0.02522628754377365
# 		Variance: 0.15882785618305206
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 0.23256862739818027
# 		Std: 0.0002228459778568791
# 		Variance: 0.014928026589502014
#
# 	Worst seeds:
# 		Mean: 0.23298659920692444
# 		Std: 0.00016559168579988182
# 		Variance: 0.012868243269622326
#
# 	Best seeds:
# 		Mean: 0.2322191745042801
# 		Std: 6.871669756947085e-05
# 		Variance: 0.008289553225040436

# %% [markdown]
# ### Plots of distributions

# %%
metric = ["MAPE"]

# %%
array0 = calculate_timeseries_means(samples0, metric, num_timeseries)
array1 = calculate_timeseries_means(samples1, metric, num_timeseries)
array2 = calculate_timeseries_means(samples2, metric, num_timeseries)
array3 = calculate_timeseries_means(samples3, metric, num_timeseries)

# %%
def plot_smoothed_histogram(data_array, mean_array, smoothing_factor=1, plot_mape=False):
    
    def moving_average(array, n):
        ret = np.cumsum(array)
        ret[n:] = ret[n:] - ret[:-n]
        return ret[n - 1:] / n

    best_indexes, best_counts = np.unique(np.argsort(data_array, axis=0)[:n], return_counts=True)
    worst_indexes, worst_counts = np.unique(np.argsort(data_array, axis=0)[-n:], return_counts=True)

    # Normalize the counts
    best_counts = best_counts / num_timeseries
    worst_counts = worst_counts / num_timeseries

    # Create histogram
    best_bin_counts = count_repetitions_among_top_n(best_indexes, best_counts, num_bins)
    worst_bin_counts = count_repetitions_among_top_n(worst_indexes, worst_counts, num_bins)
    bin_counts = best_bin_counts - worst_bin_counts

    # Sort by MAPE score
    sorting_idx = np.argsort(mean_array.flatten())
    sorted_bin_counts = bin_counts[sorting_idx]
    sorted_best_bin_counts = best_bin_counts[sorting_idx]
    sorted_worst_bin_counts = -worst_bin_counts[sorting_idx]

    # Smooth the values
    smoothed_best = moving_average(sorted_best_bin_counts, smoothing_factor)
    smoothed_worst = moving_average(sorted_worst_bin_counts, smoothing_factor)

    # Fill area between 0 and the smoothed values
    plt.fill_between(np.arange(smoothed_best.shape[0]), smoothed_best)
    plt.fill_between(np.arange(smoothed_worst.shape[0]), smoothed_worst)

    if plot_mape:
        plt.plot(mean_array[sorting_idx] - mean_array.mean(), color="C2")
    
    plt.ylim([-1, 1])
    plt.yticks([])
    plt.xticks([])

# %%
n = 10
num_bins = 100

# %%
plot_smoothed_histogram(array0, array0.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[0]}")
plt.savefig("s0.png")

# %%
plot_smoothed_histogram(array1, array1.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[1]}")
plt.savefig("s1.png")

# %%
plot_smoothed_histogram(array2, array2.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[2]}")
plt.savefig("s2.png")

# %%
plot_smoothed_histogram(array3, array3.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[3]}")
plt.savefig("s3.png")

# %%
figure = plt.Figure(figsize=(20, 20))
s0 = plt.imread("s0.png")
s1 = plt.imread("s1.png")
s2 = plt.imread("s2.png")
s3 = plt.imread("s3.png")

plt.imshow(np.hstack([s0, s1, s2, s3]))
plt.axis("off")
plt.savefig(f"/home/dev/deepts/plots/seed_distributions_sampling_{id}.png", dpi=400)
