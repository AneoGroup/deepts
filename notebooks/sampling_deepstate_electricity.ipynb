# %% [markdown]
# # Sampling DeepState
# Model: DeepState
#
# Dataset: Electricity
#
# This notebooks looks at the potential for specific random seeds to produce bad results when sampling from different models. The differences, in terms of evaluation metrics, between samples from the same architecture trained from different random seeds are calculated. Then we look for specific random seeds that produce bad model performance across the architecture.
#
# The seeds we have sampled from: 45, 47, 10, 59

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from src.metrics import *

# %%
# id used to differentiate between plots from different models/datasets
id = "deepstate_electricity"
root_path = "/datadrive/experiments/deepstate/electricity/2B"
num_timeseries = 321
seeds = [45, 47, 10, 59]

# %% [markdown]
# ### Differences in terms of error metrics

# %%
def load_samples(path):
    samples = []
    for f in os.listdir(path):
        if f.endswith("metrics.csv"):
            samples.append(pd.read_csv(f"{path}/{f}", index_col=0).rename_axis("index"))
    return samples

# %%
path0 = f"{root_path}/repetition{seeds[0]}/samples"

# %%
samples0 = load_samples(path0)

# %%
report_experiment_results(samples0)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 10813685.59036174
# 		Std: 903639.9807223033
# 		Variance: 950.5998005061348
#
# 	Worst seeds:
# 		Mean: 12338198.0
# 		Std: 447945.71875
# 		Variance: 669.2874755859375
#
# 	Best seeds:
# 		Mean: 9192240.0
# 		Std: 166894.25
# 		Variance: 408.52691650390625
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 2.894598323846834
# 		Std: 0.013372458861596099
# 		Variance: 0.115639348240969
#
# 	Worst seeds:
# 		Mean: 2.9176740646362305
# 		Std: 0.004733688198029995
# 		Variance: 0.06880180537700653
#
# 	Best seeds:
# 		Mean: 2.869877338409424
# 		Std: 0.004571332596242428
# 		Variance: 0.06761162728071213
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 0.3447217106595417
# 		Std: 0.0012117796689814176
# 		Variance: 0.034810625805656206
#
# 	Worst seeds:
# 		Mean: 0.346717894077301
# 		Std: 0.00043358677066862583
# 		Variance: 0.02082274667918682
#
# 	Best seeds:
# 		Mean: 0.34242570400238037
# 		Std: 0.0003802618011832237
# 		Variance: 0.019500302150845528

# %%
path1 = f"{root_path}/repetition{seeds[1]}/samples"

# %%
samples1 = load_samples(path1)

# %%
report_experiment_results(samples1)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 28704535.85683919
# 		Std: 967237.4984009204
# 		Variance: 983.4823325311545
#
# 	Worst seeds:
# 		Mean: 30410644.0
# 		Std: 484036.75
# 		Variance: 695.7274780273438
#
# 	Best seeds:
# 		Mean: 27155398.0
# 		Std: 232570.984375
# 		Variance: 482.2561340332031
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 2.9633130793197364
# 		Std: 0.013768843148176292
# 		Variance: 0.1173407139409689
#
# 	Worst seeds:
# 		Mean: 2.9853250980377197
# 		Std: 0.0043424079194664955
# 		Variance: 0.06589695066213608
#
# 	Best seeds:
# 		Mean: 2.937803268432617
# 		Std: 0.006871200632303953
# 		Variance: 0.08289270848035812
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 0.3884865613075057
# 		Std: 0.0014256130848406992
# 		Variance: 0.03775729181020137
#
# 	Worst seeds:
# 		Mean: 0.3909572958946228
# 		Std: 0.00043437961721792817
# 		Variance: 0.020841775462031364
#
# 	Best seeds:
# 		Mean: 0.38624584674835205
# 		Std: 0.00023807355319149792
# 		Variance: 0.015429632738232613

# %%
path2 = f"{root_path}/repetition{seeds[2]}/samples"

# %%
samples2 = load_samples(path2)

# %%
report_experiment_results(samples2)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 224770087.0170231
# 		Std: 5948804.3840618115
# 		Variance: 2439.017093843709
#
# 	Worst seeds:
# 		Mean: 235441744.0
# 		Std: 3202612.25
# 		Variance: 1789.5843505859375
#
# 	Best seeds:
# 		Mean: 215888672.0
# 		Std: 1585550.0
# 		Variance: 1259.186279296875
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 13.642110127443376
# 		Std: 0.018619418341576082
# 		Variance: 0.13645298949299747
#
# 	Worst seeds:
# 		Mean: 13.6763334274292
# 		Std: 0.006962896790355444
# 		Variance: 0.08344397693872452
#
# 	Best seeds:
# 		Mean: 13.609085083007812
# 		Std: 0.005612595938146114
# 		Variance: 0.0749172642827034
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 1.3559341154988787
# 		Std: 0.00191440204952142
# 		Variance: 0.043753880393873866
#
# 	Worst seeds:
# 		Mean: 1.3589751720428467
# 		Std: 0.0006809748592786491
# 		Variance: 0.026095494627952576
#
# 	Best seeds:
# 		Mean: 1.3523130416870117
# 		Std: 0.0008036922081373632
# 		Variance: 0.028349466621875763

# %%
path3 = f"{root_path}/repetition{seeds[3]}/samples"

# %%
samples3 = load_samples(path3)

# %%
report_experiment_results(samples3)
# Out:
# MSE SCORES
# 	All seeds:
# 		Mean: 203841267.0350281
# 		Std: 4815637.012170331
# 		Variance: 2194.4559718003757
#
# 	Worst seeds:
# 		Mean: 212989024.0
# 		Std: 2686028.5
# 		Variance: 1638.9107666015625
#
# 	Best seeds:
# 		Mean: 196088384.0
# 		Std: 1567459.75
# 		Variance: 1251.9822998046875
#
#
# MASE SCORES
# 	All seeds:
# 		Mean: 11.329346311768573
# 		Std: 0.018123030763851803
# 		Variance: 0.134621806420252
#
# 	Worst seeds:
# 		Mean: 11.363039016723633
# 		Std: 0.005858147516846657
# 		Variance: 0.07653853297233582
#
# 	Best seeds:
# 		Mean: 11.297601699829102
# 		Std: 0.005206468049436808
# 		Variance: 0.07215586304664612
#
#
# MAPE SCORES
# 	All seeds:
# 		Mean: 1.1597191705307583
# 		Std: 0.0018778811142589687
# 		Variance: 0.04333452566094348
#
# 	Worst seeds:
# 		Mean: 1.162907361984253
# 		Std: 0.0005964338197372854
# 		Variance: 0.024421995505690575
#
# 	Best seeds:
# 		Mean: 1.1563032865524292
# 		Std: 0.0008088515605777502
# 		Variance: 0.028440315276384354

# %% [markdown]
# ### Plots of distributions

# %%
metric = ["MAPE"]

# %%
array0 = calculate_timeseries_means(samples0, metric, num_timeseries)
array1 = calculate_timeseries_means(samples1, metric, num_timeseries)
array2 = calculate_timeseries_means(samples2, metric, num_timeseries)
array3 = calculate_timeseries_means(samples3, metric, num_timeseries)

# %%
def plot_smoothed_histogram(data_array, mean_array, smoothing_factor=1, plot_mape=False):
    
    def moving_average(array, n):
        ret = np.cumsum(array)
        ret[n:] = ret[n:] - ret[:-n]
        return ret[n - 1:] / n

    best_indexes, best_counts = np.unique(np.argsort(data_array, axis=0)[:n], return_counts=True)
    worst_indexes, worst_counts = np.unique(np.argsort(data_array, axis=0)[-n:], return_counts=True)

    # Normalize the counts
    best_counts = best_counts / num_timeseries
    worst_counts = worst_counts / num_timeseries

    # Create histogram
    best_bin_counts = count_repetitions_among_top_n(best_indexes, best_counts, num_bins)
    worst_bin_counts = count_repetitions_among_top_n(worst_indexes, worst_counts, num_bins)
    bin_counts = best_bin_counts - worst_bin_counts

    # Sort by MAPE score
    sorting_idx = np.argsort(mean_array.flatten())
    sorted_bin_counts = bin_counts[sorting_idx]
    sorted_best_bin_counts = best_bin_counts[sorting_idx]
    sorted_worst_bin_counts = -worst_bin_counts[sorting_idx]

    # Smooth the values
    smoothed_best = moving_average(sorted_best_bin_counts, smoothing_factor)
    smoothed_worst = moving_average(sorted_worst_bin_counts, smoothing_factor)

    # Fill area between 0 and the smoothed values
    plt.fill_between(np.arange(smoothed_best.shape[0]), smoothed_best)
    plt.fill_between(np.arange(smoothed_worst.shape[0]), smoothed_worst)

    if plot_mape:
        plt.plot(mean_array[sorting_idx] - mean_array.mean(), color="C2")
    
    plt.ylim([-1, 1])
    plt.yticks([])
    plt.xticks([])

# %%
n = 10
num_bins = 100

# %%
plot_smoothed_histogram(array0, array0.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[0]}")
plt.savefig("s0.png")

# %%
plot_smoothed_histogram(array1, array1.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[1]}")
plt.savefig("s1.png")

# %%
plot_smoothed_histogram(array2, array2.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[2]}")
plt.savefig("s2.png")

# %%
plot_smoothed_histogram(array3, array3.mean(axis=1), plot_mape=True)
plt.suptitle(f"Seed {seeds[3]}")
plt.savefig("s3.png")

# %%
figure = plt.Figure(figsize=(20, 20))
s0 = plt.imread("s0.png")
s1 = plt.imread("s1.png")
s2 = plt.imread("s2.png")
s3 = plt.imread("s3.png")

plt.imshow(np.hstack([s0, s1, s2, s3]))
plt.axis("off")
plt.savefig(f"/home/dev/deepts/plots/seed_distributions_sampling_{id}.png", dpi=400)
