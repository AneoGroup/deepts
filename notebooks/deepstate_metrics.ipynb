# %% [markdown]
# # DeepState metrics
# Model: DeepState
#
# Dataset: Electricity
#
# Here we attempt to replicate the results from deepar_metrics.ipynb and deepar_metrics_continued.ipynb. Can we find similar patterns of good and bad seeds for DeepState?

# %%
import matplotlib.pyplot as plt

from src.metrics import *

# %%
experiment_path = "/home/dev/deepts/experiments/deepstate/electricity/1B"
exp = load_data(experiment_path)

len(exp)
# Out:
# 100

# %%
exp[0].head()
# Out:
#        item_id          MSE   abs_error  abs_target_sum  abs_target_mean  \
# index
# 0          0.0   426.866333  469.668518           235.0         9.791667
# 1          1.0    45.860031  120.203552          2499.0       104.125000
# 2          2.0     0.210645    9.390136           190.0         7.916667
# 3          3.0  1457.894531  649.608521         10468.0       436.166667
# 4          4.0   293.102295  354.878113          4087.0       170.291667
#
#        seasonal_error      MASE      MAPE     sMAPE  OWA       MSIS  \
# index
# 0            8.031874  2.436483  4.137137  1.058428  NaN  10.449720
# 1            9.577165  0.522961  0.046577  0.048190  NaN   3.607383
# 2            8.673073  0.045112  0.050201  0.050460  NaN   0.349170
# 3           48.398763  0.559250  0.056887  0.059469  NaN   5.489459
# 4           25.383302  0.582532  0.096263  0.091204  NaN   3.436857
#
#        QuantileLoss[0.1]  Coverage[0.1]  QuantileLoss[0.5]  Coverage[0.5]  \
# index
# 0              81.012937       0.041667         469.668503       0.916667
# 1              66.795306       0.000000         120.203552       0.250000
# 2               7.720058       0.000000           9.390136       0.500000
# 3             355.512622       0.000000         649.608551       0.125000
# 4             113.425519       0.291667         354.878113       0.708333
#
#        QuantileLoss[0.9]  Coverage[0.9]
# index
# 0             217.061987       1.000000
# 1              48.713925       0.791667
# 2               6.816158       1.000000
# 3             332.654932       0.875000
# 4             164.137033       1.000000

# %% [markdown]
# ### Differences in metrics between different seeds

# %%
report_experiment_results(exp)
# Out:
# Most occuring repetitions worst 10 (repetition, frequency): {64: 3, 56: 3, 74: 3, 57: 3, 11: 2, 75: 2, 28: 2, 36: 2, 65: 1, 46: 1, 96: 1, 20: 1, 9: 1, 25: 1, 86: 1, 69: 1, 31: 1, 59: 1}
# Most occuring repetitions best 10 (repetition, frequency): {3: 3, 52: 3, 24: 2, 18: 2, 67: 2, 49: 2, 88: 1, 92: 1, 34: 1, 5: 1, 6: 1, 98: 1, 27: 1, 82: 1, 20: 1, 45: 1, 50: 1, 21: 1, 54: 1, 10: 1, 58: 1, 9: 1}
# Total number of different repetitions present across metrics (highest): 18
# Total number of different repetitions present across metrics (lowest): 22
#
# (MSE) Highest value: 5048482.5
# (MSE) Lowest value:  1894705.75
# (MSE) Difference between highest and lowest: 3153776.75
# (MSE) Difference between average error, 10 highest - 10 lowest: 1884352.25
#
# (MASE) Highest value: 1.0889883041381836
# (MASE) Lowest value:  0.9063681960105896
# (MASE) Difference between highest and lowest error: 0.182620108127594
# (MASE) Difference between the average error, 10 highest - 10 lowest: 0.09869617223739624
#
# (MAPE) Highest value: 0.1638718843460083
# (MAPE) Lowest value:  0.1381099820137024
# (MAPE) Difference between highest and lowest: 0.025761902332305908
# (MAPE) Difference between average error, 10 highest - 10 lowest: 0.013292193412780762

# %% [markdown]
# ### The best and worst metric-value for all timeseries. Which repetitions are most common?

# %%
metric = ["MAPE"]

# %%
exp_array = calculate_timeseries_means(exp, metric, 321)
exp_array.shape
# Out:
# (100, 321, 1)

# %%
exp[0].head(10)
# Out:
#        item_id         MSE   abs_error  abs_target_sum  abs_target_mean  \
# index
# 0          0.0  426.866333  469.668518           235.0         9.791667
# 321        0.0  163.650197  257.480377           264.0        11.000000
# 642        0.0  170.562887  262.342590           284.0        11.833333
# 963        0.0  107.429728  223.939789           189.0         7.875000
# 1284       0.0  165.549011  269.083191           166.0         6.916667
# 1605       0.0  186.288737  283.679535           154.0         6.416667
# 1926       0.0   67.214717  178.990082           207.0         8.625000
# 1          1.0   45.860031  120.203552          2499.0       104.125000
# 322        1.0   46.452530  145.453308          2351.0        97.958333
# 643        1.0   19.738364   91.804916          2427.0       101.125000
#
#        seasonal_error      MASE      MAPE     sMAPE  OWA       MSIS  \
# index
# 0            8.031874  2.436483  4.137137  1.058428  NaN  10.449720
# 321          8.026991  1.336534  2.859490  0.815176  NaN   6.886401
# 642          8.025109  1.362093  1.895919  0.727328  NaN   6.925060
# 963          8.024132  1.162845  2.687130  0.892732  NaN   7.092622
# 1284         8.019890  1.397999  2.237513  1.528171  NaN   6.975426
# 1605         8.016509  1.474455  1.988508  1.761751  NaN   7.139952
# 1926         8.010442  0.931025  1.309289  1.180421  NaN   7.128097
# 1            9.577165  0.522961  0.046577  0.048190  NaN   3.607383
# 322          9.571517  0.633186  0.064213  0.061766  NaN   3.776864
# 643          9.567923  0.399795  0.037592  0.037424  NaN   2.131641
#
#        QuantileLoss[0.1]  Coverage[0.1]  QuantileLoss[0.5]  Coverage[0.5]  \
# index
# 0              81.012937       0.041667         469.668503       0.916667
# 321            89.392786       0.000000         257.480380       0.875000
# 642            86.945643       0.000000         262.342593       0.958333
# 963            90.681048       0.000000         223.939794       0.916667
# 1284          169.317282       0.000000         269.083217       0.291667
# 1605          190.880438       0.000000         283.679546       0.083333
# 1926          158.124492       0.000000         178.990084       0.291667
# 1              66.795306       0.000000         120.203552       0.250000
# 322            40.731194       0.166667         145.453300       0.916667
# 643            47.793813       0.000000          91.804916       0.625000
#
#        QuantileLoss[0.9]  Coverage[0.9]
# index
# 0             217.061987       1.000000
# 321           173.241381       0.958333
# 642           179.811315       1.000000
# 963           182.497218       1.000000
# 1284           99.205019       1.000000
# 1605           83.859492       1.000000
# 1926          115.951715       1.000000
# 1              48.713925       0.791667
# 322            82.007675       1.000000
# 643            50.103992       1.000000

# %%
exp_max_bin, exp_worst_reps = find_n_most_frequent_repetitions(exp_array, 5, np.argmax)
plt.hist([i for i in range(100)], bins=100, range=(0, 100), weights=exp_max_bin)
plt.title(f"Worst {metric} score")
plt.xlabel("Repetition ID")
plt.ylabel("Frequency")

exp_max_bin, exp_worst_reps
# Out:
# (array([ 1,  3,  9,  1,  1,  0,  2,  2,  2,  1,  0, 21,  3,  4,  2,  1,  0,
#          0,  0,  1,  1,  0,  1,  2,  1,  5,  2,  2, 21,  3,  0,  1,  1,  3,
#          2,  2,  5,  0,  2,  2,  0,  1,  0,  2,  3,  2,  0,  9,  0,  0,  2,
#          6,  1,  0,  0,  4, 14, 83,  0,  0,  0,  1,  0,  1, 12,  3,  1,  0,
#          0,  1,  1,  0,  1,  1,  9,  8,  1,  1,  1,  1,  5,  4,  7,  1,  1,
#          1,  4,  0,  1,  0,  0,  3,  2,  2,  0,  0,  8,  1,  1,  0]),
#  array([64, 56, 28, 57, 11]))

# %%
exp_min_bin, exp_best_reps = find_n_most_frequent_repetitions(exp_array, 5, np.argmin)
plt.hist([i for i in range(100)], bins=100, range=(0, 100), weights=exp_min_bin)
plt.title(f"Best {metric} score")
plt.xlabel("Repetition ID")
plt.ylabel("Frequency")

exp_min_bin, exp_best_reps
# Out:
# (array([ 5,  1,  3, 10,  2,  5,  2,  6,  0,  5,  4,  3,  0,  6,  4,  3,  0,
#          3, 10,  7,  5,  4,  4,  0, 21,  4, 10,  3,  0,  2,  4,  0,  2, 13,
#          3,  9,  2,  2,  0,  0,  0,  0,  0,  1,  0,  4,  1,  1,  3, 19,  5,
#          4,  6,  1,  6,  4,  2,  2,  3,  1,  2,  3,  2,  1,  0,  2,  1,  4,
#          1,  1,  1,  3,  4,  0,  0,  2,  2,  3,  1,  4,  1,  4,  1,  3,  7,
#          2,  1,  0,  4,  6,  3,  1,  3,  2,  2,  2,  7,  1,  1,  3]),
#  array([18, 26, 33, 49, 24]))

# %% [markdown]
# ### The top n best and worst scoring seeds

# %%
n = 10

# %%
indexes_worst10, worst10 = np.unique(np.argsort(exp_array, axis=0)[-n:], return_counts=True)
worst_10_count = count_repetitions_among_top_n(indexes_worst10, worst10, 100)
plt.title(f"Worst 10 {metric} scores")
plt.xlabel("Repetition ID")
plt.ylabel("Frequency")

plt.hist([i for i in range(100)], bins=100, range=(0, 100), weights=worst_10_count)

worst_10_count, np.argsort(worst_10_count)[-10:][::-1], worst_10_count[np.argsort(worst_10_count)[-10:][::-1]]
# Out:
# (array([ 17.,  24.,  42.,  14.,  19.,  21.,  56.,  17.,  30.,   7.,  23.,
#          89.,  40.,  39.,  18.,  10.,   6.,   8.,   3.,  15.,  22.,  13.,
#          14.,  28.,  12.,  82.,  19.,  40., 108.,  77.,  24.,  51.,  51.,
#          41.,  35.,  24.,  67.,  12.,  35.,  28.,  25.,  21.,  15.,  45.,
#          37.,  14.,  27.,  68.,  19.,   5.,  16.,  43.,   5.,  20.,   9.,
#          25., 105., 151.,  13.,  40.,  14.,  24.,  36.,  28.,  74.,  35.,
#          30.,  11.,   7.,  37.,   6.,  38.,   9.,  11.,  88.,  99.,  50.,
#          18.,  12.,   9.,  44.,  40.,  43.,  40.,  27.,  15.,  51.,  27.,
#          28.,  18.,  11.,  51.,  17.,  21.,  18.,  41.,  52.,  20.,  17.,
#           9.]),
#  array([57, 28, 56, 75, 11, 74, 25, 29, 64, 47]),
#  array([151., 108., 105.,  99.,  89.,  88.,  82.,  77.,  74.,  68.]))

# %%
indexes_best10, best10 = np.unique(np.argsort(exp_array, axis=0)[:n], return_counts=True)
best_10_count = count_repetitions_among_top_n(indexes_best10, best10, 100)
plt.title(f"Best 10 {metric} scores")
plt.xlabel("Repetition ID")
plt.ylabel("Frequency")

plt.hist([i for i in range(100)], bins=100, range=(0, 100), weights=best_10_count)

best_10_count, np.argsort(best_10_count)[-10:][::-1], best_10_count[np.argsort(best_10_count)[-10:][::-1]]
# Out:
# (array([26., 21., 31., 61., 23., 37., 27., 42., 16., 51., 23., 35., 16.,
#         50., 31., 25., 40., 37., 86., 50., 42., 37., 43., 23., 94., 23.,
#         67., 31.,  4., 11., 23.,  8., 18., 46., 30., 64., 13., 41., 19.,
#         10.,  5.,  7., 17., 20., 21., 44., 26., 25., 43., 78., 57., 30.,
#         78., 29., 58., 62., 21., 16., 33., 11., 27., 36., 23., 31., 19.,
#         40., 21., 63., 43., 23., 24., 19., 36., 20.,  8., 22., 30., 38.,
#         14., 51., 20., 31., 36., 23., 46., 38., 10., 14., 31., 28., 32.,
#         25., 35., 20., 33., 24., 42., 23., 24., 31.]),
#  array([24, 18, 49, 52, 26, 35, 67, 55,  3, 54]),
#  array([94., 86., 78., 78., 67., 64., 63., 62., 61., 58.]))
